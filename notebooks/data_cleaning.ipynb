# %% [markdown]
# # Yelp Dataset Exploration and Cleaning 🔍🧼

# %% [markdown]
# ## Call in the proper libraries 🧾

# %%
#since this is just exploration and cleaning we only need the essentials
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Call in the Dataset 📃

# %%
# Using pd.read_json() didn't work.
# We will make our own data frame.
data = []
with open('../raw_data/unpacked_json_files/yelp_academic_dataset_business.json', 'r') as file:
    for line in file:
        try:
            json_data = json.loads(line)
            data.append(json_data)
        except json.JSONDecodeError:
            # Handle any invalid JSON lines here
            pass

# Create a DataFrame from the loaded JSON objects
business_df = pd.DataFrame(data)

# Display the DataFrame
business_df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
# trying to see if there are any tokyo places.
tokyo_df = business_df[business_df['city']=='Tokyo']

# %%
# There are not...
tokyo_df
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
# Checking to see what the most popular state is.
business_df['state'].value_counts()
# Out:
# state
# PA     34039
# FL     26330
# TN     12056
# IN     11247
# MO     10913
# LA      9924
# AZ      9912
# NJ      8536
# NV      7715
# AB      5573
# CA      5203
# ID      4467
# DE      2265
# IL      2145
# TX         4
# CO         3
# WA         2
# HI         2
# MA         2
# NC         1
# UT         1
# MT         1
# MI         1
# SD         1
# XMS        1
# VI         1
# VT         1
# Name: count, dtype: int64

# %% [markdown]
# ### Initial thoughts
# - Turns out this is just yelp data from the USA
# - The most popular State happens to be 'PA' the 'FL'
# - This data set cannot be use for a Japanese resturant recommender app
# - It is still useful in other ways, perhaps we can make a philidelphia app or something in the same vain.
# - This isn't just a food yelp data set it is an every kind of establishment data set.

# %%
# Isolating the Philidelphia dataset
pa_df = business_df[business_df['state']=='PA']

# %%
# Checking to see what it looks like. 
pa_df.head()
# Out:
#                business_id                           name        address  \
# 3   MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries    935 Race St
# 4   mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery  101 Walnut St
# 15  MUTTqe8uqyMdBl186RmNeA                       Tuna Bar    205 Race St
# 19  ROeacJQwBeh05Rqg7F6TCg                            BAP  1224 South St
# 25  PSo_C1Sfa13JHjzVNW6ziQ  Indian Walk Veterinary Center  662 Durham Rd
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 3   Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 4     Green Lane    PA       18054  40.338183 -75.471659    4.5            13
# 15  Philadelphia    PA       19106  39.953949 -75.143226    4.0           245
# 19  Philadelphia    PA       19147  39.943223 -75.162568    4.5           205
# 25       Newtown    PA       18940  40.273493 -74.987496    5.0            15
#
# ...

# %%
#trying to check the different catagories just incase we do decied to use this. 
pa_df['categories'].value_counts()
# Out:
# categories
# Restaurants, Pizza                                                                                                          318
# Pizza, Restaurants                                                                                                          294
# Beauty & Spas, Nail Salons                                                                                                  260
# Nail Salons, Beauty & Spas                                                                                                  243
# Chinese, Restaurants                                                                                                        184
#                                                                                                                            ...
# Paint Stores, Hardware Stores, Building Supplies, Home & Garden, Shopping, Home Services                                      1
# ...
